# %% [markdown]
# ![Facial Recognition](../data/atividade_7/facialrecognition.jpg)

# %% [markdown]
# Você é membro de um grupo de elite de cientistas de dados, especializado em tecnologia avançada de reconhecimento facial, esta empresa é dedicada a identificar e proteger indivíduos proeminentes de várias esferas — variando de entretenimento e esportes a política e filantropia. A missão da equipe é implantar soluções orientadas por IA que podem distinguir com precisão entre imagens de personalidades notáveis ​​e a população em geral, aumentando a segurança pessoal de tais indivíduos de alto perfil. Você deve se concentrar em Arnold Schwarzenegger, uma figura cujas realizações abrangem de campeão de fisiculturismo a ícone de Hollywood, e de filantropo a governador da Califórnia.

# %% [markdown]
# ### **Os Dados**
# O conjunto de dados `data/atividade_7/lfw_arnie_nonarnie.csv` contém dados de imagens faciais processadas derivadas do conjunto de dados "Labeled Faces in the Wild" (LFW), com foco específico em imagens de Arnold Schwarzenegger e outros indivíduos não identificados como ele. Este conjunto de dados foi preparado para auxiliar no desenvolvimento e avaliação de modelos de reconhecimento facial. Há 40 imagens de Arnold Schwarzenegger e 150 de outras pessoas.
#
# | Nome da coluna | Descrição |
# |-------------|-------------|
# | PC1, PC2, ... PCN | Componentes principais do PCA, capturando características-chave da imagem. |
# | Rótulo | Indicador binário: `1` para Arnold Schwarzenegger, `0` para outros. |

# %%
import pandas as pd
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV, KFold, train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("data/atividade_7/lfw_arnie_nonarnie.csv")

X = df.drop('Label', axis=1)
y = df['Label'] 

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=21, stratify=y)
